# %%
# Import the required libraries
import pandas as pd
from sqlalchemy import create_engine

# %%
#Step 1: Load the data 
df = pd.read_csv(r'C:\Users\cocou\OneDrive\Desktop\Portfolio\Data Analysis\Pizza-Sales-End-to-End-Analysis\data\pizza_sales.csv')
df.sample(frac=0.005)
# Out:
#        pizza_id  order_id   pizza_name_id  quantity  order_date order_time  \
# 15590     15591      6831      thai_ckn_l         1  25-04-2015   13:44:04
# 10193     10194      4466      cali_ckn_s         1  16-03-2015   19:51:03
# 34178     34179     15089   ital_veggie_s         1  09-09-2015   21:24:07
# 38274     38275     16884      thai_ckn_l         1  14-10-2015   12:07:21
# 32732     32733     14469  peppr_salami_s         1  29-08-2015   21:46:42
# ...         ...       ...             ...       ...         ...        ...
# 10608     10609      4645       bbq_ckn_l         1  19-03-2015   19:21:02
# 17873     17874      7843     the_greek_s         1  12-05-2015   14:59:06
# 43931     43932     19311     pepperoni_s         1  26-11-2015   12:40:36
# 22           23         9    veggie_veg_s         1  01-01-2015   12:52:01
# 11924     11925      5234    prsc_argla_m         1  29-03-2015   19:05:13
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
# Step 2: Connect to Postgres
engine = create_engine("postgresql://postgres:Mariette%401967@localhost:5432/PizzaDB")

# %%
#Step 3: Export the dataframe to SQL

table_name = 'pizza_sales'
df.to_sql(table_name, engine, if_exists='replace', index=False)

print(f'Table {table_name} exported and data inserted successfully!')
# Out:
# Table pizza_sales exported and data inserted successfully!
